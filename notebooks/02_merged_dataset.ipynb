# %%
import pandas as pd
import numpy as np
import os

# %%
student_file = "../data/processed/cleaned_student_dataset.csv"
reddit_file =  "../data/processed/cleaned_reddit_dataset.csv"

student_df = pd.read_csv(student_file)
reddit_df = pd.read_csv(reddit_file)

# %% [markdown]
# # MERGED HYBRID DATASET (STUDENT DATA AND REDDIT DATA)

# %%
import pandas as pd

# Load the cleaned Reddit dataset
reddit_clean_path = "../data/processed/cleaned_reddit_dataset.csv"
reddit_clean = pd.read_csv(reddit_clean_path)

# Ensure both datasets have consistent column names
student_df = student_df[['serialized_text', 'Depression']].rename(columns={'serialized_text': 'clean_text', 'Depression': 'binary_label'})

# Combine the Student and Reddit datasets
combined_df = pd.concat([reddit_clean, student_df[['clean_text', 'binary_label']]], ignore_index=True)

# Shuffle the dataset to mix Reddit and Student data
combined_df = combined_df.sample(frac=1).reset_index(drop=True)

# Save the combined dataset to a CSV file
combined_output_path = "../data/processed/combined_hybrid_student_reddit_data.csv"
combined_df.to_csv(combined_output_path, index=False)

# Display the first few rows of the combined dataset
combined_df.head()
# Out:
#    binary_label                                         clean_text
# 0             1  A 24-year-old Male student with CGPA 2.8, 5.0 ...
# 1             0  A 24-year-old Male student with CGPA 3.95, 3.0...
# 2             1  so now i am stuck on cellular and cannot do an...
# 3             1  A 28-year-old Male student with CGPA 4.86, 5.0...
# 4             1  i stopped my dad from killing himself yesterda...

# %%
combined_df["binary_label"].nunique()
# Out:
# 2

# %%
combined_df["binary_label"].value_counts()
# Out:
# binary_label
# 1    42392
# 0    27908
# Name: count, dtype: int64

# %%
combined_df["clean_text"][4]
# Out:
# 'i stopped my dad from killing himself yesterday and idk what i should do i don t know how to help him i offered to help him talk to a therapist but he said no i m afraid to lose him when i pulled the gun out of his hand he looked so scared and overwhelmed he even said thank you for now i took the gun from the house i hope to god it wa just a one off and he won t try again but i don t know how to help i know i can call 9 and they will put him in a hospital for his own safety i don t know i m scared of doing that he doesn t like hospital any help would be appreciated i m completely lost'

# %%
combined_df.shape
# Out:
# (70300, 2)
